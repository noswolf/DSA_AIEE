# %% [markdown]
# # Lab 3: Plotting with matplotlib and Big-O
#
# Lecturer: <code>Sirasit Lochanachit</code>
#
# Course:
#
# <code>01546203 Data Structures and Algorithms [SIIE]
# </code>
#
# Term: <code>01/2026</code>
#
# ---

# %% [markdown]
# # Required Libraries

# %% [markdown]
# - pip install numpy
# - pip install matplotlib

# %%
import time
import timeit
import math
import random
import numpy as np
import matplotlib.pyplot as plt

# %% [markdown]
# ---

# %% [markdown]
# ## 1. Drawing plots with `matplotlib`

# %% [markdown]
# The [matplotlib library](https://matplotlib.org) supports the creation of all sorts of visualizations. We will use it for drawing simple 2-dimensional plots.
#
# All types of matplotlib's plot can be explored here: https://matplotlib.org/stable/plot_types/index
#
# The primary plotting function we will use is `matplotlib.pyplot.plot` ([full documentation here](https://matplotlib.org/api/_as_gen/matplotlib.pyplot.plot.html#matplotlib.pyplot.plot)), which, when passed two "array-like" objects of equal length, will interpret and plot their contents as x and y axis coordinates. We will generally use tuples, lists, and ranges as array-like objects. Note that generators are *not* considered array-like by matplotlib.
#
# Some examples (note that we use a semicolon after the call to `plot` to hide its return value):

# %%
import matplotlib.pyplot as plt
import numpy as np
import math

# %matplotlib inline
# setting plot size
plt.rcParams['figure.figsize'] = [10, 6] # [wide, tall]

# %% [markdown]
# `plt.plot()` is used to create a 2D line plot
#
# - The first list [1, 2, 3, 4, 5] represents the x-coordinates.
# - The second list [50, 20, 30, 10, 40] represents the y-coordinates.

# %%
plt.plot([1, 2, 3, 4, 5], [50, 20, 30, 10, 40]);

# %% [markdown]
# What kind of line plot do you think this code will draw?

# %%
xs = range(11)
ys = [x*2 for x in xs]
plt.plot(xs, ys);

# %% [markdown]
# > **Explanation**
#
# `range(11)` generates numbers from 0 to 10
#
# If `xs = [0, 1, 2, ..., 10]`, then `ys = [0*2, 1*2, 2*2, ..., 10*2]`.

# %% [markdown]
# We can also provide an optional format string to `plot`, which controls marker, line-style, and color for the plot.
#
# Here's a shortened list of options copied from the [full documentation of `plot`](https://matplotlib.org/api/_as_gen/matplotlib.pyplot.plot.html#matplotlib.pyplot.plot):
#
# **Markers**
#
#   - `.` : point marker
#   - `o` : circle marker
#   - `s` : square marker
#   - `d` : diamond marker
#
# **Line-styles**
#
#   - `-` : solid line style
#   - `--` : dashed line style
#   - `:` : dotted line style
#
# **Colors**
#
#   - `k` : black
#   - `r` : red
#   - `b` : blue
#   - `g` : green
#   - `y` : yellow
#   - `c` : cyan
#
# Here are the above plots with some color and styling:

# %%
plt.plot([1, 2, 3, 4, 5], [50, 20, 30, 10, 40], 'o--c');

# %% [markdown]
# If we omit a line style, no connecting line is drawn between data points

# %%
xs = range(11)
ys = [x*2 for x in xs]
plt.plot(xs, ys, 'dg');

# %% [markdown]
# Instead of regular `range` objects, which only allow for integral start/stop/step values, we typically prefer to use the [numpy library](https://numpy.org)'s `arange` and `linspace` functions with matplotlib.
# - `arange` is like `range`, except we can use floating point values for start/stop/step.
# - `linspace` lets us specify start and stop values (both inclusive), and the number of values to return in that interval.
#
# Examples of `arange` and `linspace` calls (note that both functions return numpy arrays, which are iterable and can be passed to `plot`):

# %% [markdown]
# Obtain values betweeen 0.5 and 2.5 with 0.1 step

# %%
np.arange(0.5, 2.5, 0.1)

# %% [markdown]
# Obtain 41 values that are evenly spaced between 10 and 20

# %%
np.linspace(10, 20, 41)

# %%
np.linspace(1, 100000, 50, dtype=int) # we can specify the data type to coerce values into integers

# %% [markdown]
# `plot` can be called multiple times in the same cell to draw multiple lines in the same chart. Below we use this facility together with `linspace` and a handful of list comprehensions to plot some common runtime complexity bounding functions (more on that soon) over a small interval:

# %% [markdown]
# ---

# %% [markdown]
# # Lab 3-1 Basic Plotting
#
# Given values of x between 0.1 and 4 in `xs` variable, produce a plot of running time complexity of 6 most important functions (except factorial)
#
# * Plotting Factorial function can get ugly very fast (You can try it!)
# * Your plot should include x and y label, a legend, and a title

# %%
count = 100
xs = np.linspace(0.1, 4, count) # 100 evenly spaced values from 0.1 to 4

###################################
# Insert or edit your code here #
ys_const        = []
ys_log          = []
ys_linear       = []
ys_linearithmic = []
ys_quadratic    = []
ys_exponential  = []
###################################

plt.plot(xs, ys_const, 'c', label='O(1)')
plt.plot(xs, ys_log, 'r', label='O(log n)')
plt.plot(xs, ys_linear, 'b', label='O(n)')
plt.plot(xs, ys_linearithmic, 'g', label='O(n log n)')
plt.plot(xs, ys_quadratic, 'y', label='O(n^2)');
plt.plot(xs, ys_exponential, 'm', label='O(2^n)');

##################################################################
# Insert your code here x and y label, a legend, and a title#
##################################################################

# %% [markdown]
# ---

# %% [markdown]
# ## 2. Plotting timings

# %% [markdown]
# Plotting timing data collected from functions may help give us a sense of how their runtimes scale with **increasing input sizes**.

# %% [markdown]
# #### Good to know
#
# `timeit.timeit` Parameters

# %%
timeit.timeit(stmt='pass', setup='pass', number=1000000, globals=None)

# %% [markdown]
# `stmt`: The statement you want to measure, this should be callable or string
#
# `setup`: Setup details that need to be executed before timing begins. Use it to import modules or define variables.
#
# `number`: Is the number of times to execute `stmt`. More iterations provide more stable results by averaging over multiple runs.
#
# `globals`: A dictionary containing global variables to pass to the `stmt` and `setup`.

# %% [markdown]
# ### Example of measuring runtime behaviour of a **normal sum** function on different input sizes

# %%
# runtimes for sum for increasing sizes of input

# 1. Define input sizes
ns = np.linspace(10, 10000, 50, dtype=int) # 50 evenly spaced values from 10 to 10000

# 2. Measure execution times
ts = [timeit.timeit(f'sum(range({n}))', number=100)
      for n in ns]

# 3. Plot the results
plt.plot(ns, ts, 'or');
plt.xlabel('Input Size (n)')
plt.ylabel('Time Executed (in seconds)')
plt.title('Running time of sum function on 100 rounds')

# %% [markdown]
# **Tips for Accurate Benchmarking**
#
# Increase `number`: Use a large number (e.g., 1000 or more) to reduce noise from external factors.

# %% [markdown]
# ### Measuring Execution Time of an **exponential sum** function i.e. `f(n)=n^2`

# %%
# Define input sizes
ns = np.linspace(10, 10000, 50, dtype=int) # 50 evenly spaced values from 10 to 10000

ts = [timeit.timeit('sum([i**2 for i in range(n)])', setup=f'n={n}', number=1000)
      for n in ns]

plt.plot(ns, ts, '-o', label='Execution Time')
plt.xlabel('Input Size (n)')
plt.ylabel('Execution Time (seconds)')
plt.title('Execution Time of f(n) = n^2')

# %% [markdown]
# Clearly, the runtime of `sum` is directly proportional to the number of values it operates on.
#
# If we assume a linear relationship, we can compute the average slope between adjacent data points to come up with an line of approximate fit that may help us predict the runtime of `sum`.

# %%
total = 0

for i in range(len(ns)-1):
    total += (ts[i+1] - ts[i]) / (ns[i+1] - ns[i]) # recall: slope = rise / run
    
avg_slope = total / (len(ns)-1)

# %%
avg_slope

# %% [markdown]
# We can also use the statistics module to help us compute the mean:

# %%
import statistics
avg_slope = statistics.mean((ts[i+1] - ts[i]) / (ns[i+1] - ns[i]) for i in range(len(ns)-1))
avg_slope

# %% [markdown]
# Add the slope line

# %%
plt.plot(ns, ts, 'or')
plt.plot(ns, [avg_slope*n for n in ns], '--b');

# %% [markdown]
# ---

# %% [markdown]
# ## 3. Timing Examples

# %% [markdown]
# ### Built-in list indexing
#
# What is the runtime behavior of list-indexing? i.e. accessing each element in a list one-by-one (from start to finish)

# %%
lst = list(range(1000000))
ns = np.linspace(0, len(lst), 1000, endpoint=False, dtype=int)
ts = [timeit.timeit(f'_ = lst[{n}]',
                    globals=globals(), 
                    number=10000) 
      for n in ns]

plt.plot(ns, ts, 'or');
plt.xlabel('Input Size (n)')
plt.ylabel('Time Executed (in seconds)')
plt.title('Running time of list-indexing on 10000 rounds')

# %% [markdown]
# Observation: accessing an element in a list by index -- *regardless of where in the list the element is located* -- takes a uniform/constant amount of time.
#
# How? **A Python list uses an array as its backing data store.** Every "slot" in this array is a reference (i.e., a fixed-width address) to an object, and to access an element at a particular index, the underlying code:
#
# 1. Computes an *offset* into the array by multiplying the index by the size of a reference
# 2. Adds the computed offset to the *base address* of the array, giving us the address of the reference
# 3. Accesses the reference and uses it to load the associated element
#
# Each of the steps above can be performed in constant time.

# %% [markdown]
# ---

# %% [markdown]
# # Lab 3-2 Linear Search

# %% [markdown]
# Even though Python fundamentally provides an efficient way to access an element in a list, including searching for an element using built-in methods, implementing these foundational algorithms from scratch is essential for understanding how they work under the hood. This lab part attempts to **introduce you to the mechanics of sequential data traversal by having you write your own linear search function**. By implementing it manually, you will gain a deeper appreciation for algorithmic efficiency, which will later allow you to compare your custom implementation against Python's highly optimized built-in search functions in terms of execution time.

# %% [markdown]
# ## 3.1 Problem Description
#
# Write a custom function `linear_search` that accepts two inputs: a list and an integer of a target value
# * Linear search is a simple searching algorithm that checks each element in a list one by one until the target value is found or the list ends.
# * If the target value is found, return True
# * Otherwise, it looks at the next index and repeatedly do this until the last element of the list.
#     * If a list does not contain a target value, return "Target not found"
#
#
# ## Constraints
# - Built-in functions `enumerate()`, `index()`, or `slicing ([:])` are not allowed.
# - Use basic loops and indexing only

# %%
# Your custom linear search function

def linear_search(lst:list, target:int):

    #######################
    # Insert your code here
    #######################

    pass

# %% [markdown]
# ### Testing Codes

# %%
data = [10,20,40,50]
linear_search(data,40)

# %%
linear_search(data,100)

# %% [markdown]
# ### Structured Test Case
#
# Run the following code and see the result:
# - If all tests pass, you'll see 'All test cases passed' (which is good!).
# - If a test fails, you'll see an AssertionError indicating which test case failed and why.

# %%
def test_linear_search():
  test_cases = [
      {'input': {'arr': [4, 2, 7, 1, 9], 'target': 7}, 'expected': True},
      {'input': {'arr': [1, 2, 3, 4, 5], 'target': 1}, 'expected': True},
      {'input': {'arr': [1, 2, 3, 4, 5], 'target': 5}, 'expected': True},
      {'input': {'arr': [1, 2, 3, 4, 5], 'target': 6}, 'expected': "Target not Found"},
      {'input': {'arr': [], 'target': 5}, 'expected': "Target not Found"},
      {'input': {'arr': [5], 'target': 5}, 'expected': True},
      {'input': {'arr': [5], 'target': 6}, 'expected': "Target not Found"}
  ]

  for case in test_cases:
    arr = case['input']['arr']
    target = case['input']['target']
    expected = case['expected']
    result = linear_search(arr, target)
    assert result == expected, f"For input {arr}, target {target}: expected {expected}, but got {result}"
  print("\n#############################################")
  print("All test cases passed!")
  print("#############################################")

# Run the tests:
if __name__ == "__main__":
  test_linear_search()
# Out:
# #############################################
# All test cases passed!
# #############################################

# %% [markdown]
# Bonus: Testing your function on a list of 1 to 100 with a random shuffling of their positions

# %%
import random
lst = list(range(100))
random.shuffle(lst)

target = 10
print(f"Searching for {target} in lst: {linear_search(lst, target)}")

# %% [markdown]
# ---

# %% [markdown]
# ## 3.2 Comparing runtime behaviour between built-in method and your own linear search function

# %% [markdown]
# The comparison will perform on various input sizes to determine how both functions scale as the input size increases.
#
# The example target is based on worst-case scenario.

# %% [markdown]
# ### Why Use a Worst-Case Scenario Target?
#
# When benchmarking search algorithms, we intentionally use a target that is **not in the list** (or placed at the very end) to measure the algorithm's **worst-case time complexity**.
#
# If we searched for a target that was randomly placed, a lucky shuffle might position the target at index 0 for one test run. The algorithm would find it instantly, taking near-zero time ($O(1)$ best-case performance). This randomness introduces erratic "noise" into our data, resulting in a jagged, unpredictable plot.
#
# By forcing a worst-case scenario, we guarantee that every single test run forces both algorithms to traverse the entire list **from start to finish**. This eliminates luck as a factor, standardizes our measurements, and gives us a clean, stable look at how the algorithm scales in the absolute worst conditions ($O(n)$ time complexity).

# %% [markdown]
# 1) What is the runtime behaviour of Python's highly optimized built-in search function via `list.index()` method?
# - The method returns the first occurence of searched element

# %% [markdown]
# Checkout the codes in this section: what do they do?

# %%
# 1. Setup the input sizes and a worst-case target value
ns2 = np.linspace(10, 10000, 100, dtype=int)
target = 999999  # Example target (e.g., forcing a worst-case scenario search)
#target = 100 # Another example target (see if this changes the results)

# 2. Pre-generate the exact same lists for BOTH tests
# This stores a dictionary of { size: shuffled_list }
test_lists = {}
for n in ns2:
    lst = list(range(n))
    random.shuffle(lst)
    test_lists[n] = lst

# 3. Benchmark Python's built-in .index()
ts1 = []
for n in ns2:
    current_list = test_lists[n] # Get the pre-shuffled list
    t = timeit.timeit(
        'try: current_list.index(target)\nexcept ValueError: pass', # Handles "Target not found" without crashing
        globals=globals(),
        number=100
    )
    ts1.append(t)

# %%
plt.plot(ns2, ts1, 'ob');
plt.xlabel('Input Size (n)')
plt.ylabel('Time Executed (in seconds)')
plt.title("Running time of Python's built-in search function .index() on 100 rounds")

# %% [markdown]
# Do they look fast to you?

# %% [markdown]
# 2) What is the runtime behavior of searching by your custom linear search function?

# %%
# 4. Benchmark your custom linear_search using the EXACT SAME lists
ts2 = []
for n in ns2:
    current_list = test_lists[n] # Get the identical pre-shuffled list
    t = timeit.timeit(
        #################################################################
        ## Insert your code here to call your linear_search function ## 
        #################################################################,
        globals=globals(),
        number=100
    )
    ts2.append(t)

# %%
plt.plot(ns2, ts2, 'or');
plt.xlabel('Input Size (n)')
plt.ylabel('Time Executed (in seconds)')
plt.title("Running time of custom linear search on 100 rounds")

# %% [markdown]
# 3) Can you spot the difference between these two results?
#
# - Maybe combining both plots should give you clearer comparison.

# %%
# 6. Plotting both results together
plt.plot(ns2, ts1, '-b', label='Built-in .index()')
plt.plot(ns2, ts2, '-r', label='Custom linear_search()')

# Adding labels, title, and a legend
plt.xlabel('Input Size (n)')
plt.ylabel('Time Executed (in seconds)')
plt.title('Execution Time: Built-in .index() vs Custom Linear Search')
plt.legend()
plt.grid(True)

# %% [markdown]
# 4) What do you learn from this plot?
#
# - Why is one method faster than the other one?
# - Can you figure the magic behind this?

# %% [markdown]
# ---

# %% [markdown]
# *Big Note: 3.3 to 3.5 focuses only on your custom linear search function

# %% [markdown]
# ## 3.3 What is the runtime behavior of searching for an exist target in an unsorted list? Plot the graph to answer this.
#
# * Input size (`n`) grows from 10 to 10000
# * Setup the experiment by creating a list from 0 to `n`, then shuffle the list randomly to unsort it.
#     * Each test should execute `100` rounds
#     * Each round should search for the same target
# * Your plot should include x and y label and a title

# %% [markdown]
# Setup

# %%
ns3 = np.linspace(10, 10000, 100, dtype=int)

test_lists_2 = {}
for n in ns3:
    lst = list(range(n))
    random.shuffle(lst)
    test_lists_2[n] = lst

# %%
target = ## Add your code here to set a target value for the search ##

ts3 = []
for n in ns3:
    ##################################################################
    ## Add your code here to call your linear_search function ##
    ##################################################################
    pass # remove this line and replace it with your code to call linear_search

# %% [markdown]
# Plot the results

# %%
plt.plot(ns3, ts3, 'or');
##################################################################
# Add your code on xlabel, ylabel, and title here
##################################################################

# %% [markdown]
# ## 3.4 What is the runtime behavior of searching for a non-exist element in an unsorted list?
#
# * Input size (`n`) grows from 10 to 10000
# * Setup the experiment by creating a list from 0 to `n`, then shuffle the list randomly to unsort it.
#     * Each test should execute `100` rounds
#     * Each round should search for the same target
# * Your plot should include x and y label and a title

# %%
target = ## Add your code here to set a target value for the search ##

ts4 = []
for n in ns3:
    ##################################################################
    ## Add your code here to call your linear_search function ##
    ##################################################################
    pass # remove this line and replace it with your code to call linear_search

# %% [markdown]
# Plot the results

# %%
plt.plot(ns3, ts4, 'or');
##################################################################
# Add your code on xlabel, ylabel, and title here
##################################################################

# %% [markdown]
# ## 3.5 Combine both plot to compare running time

# %% [markdown]
# * Combine both plot into a single plot
# * Your plot should include x and y label, a legend, and a title
#
# After plotting, have a look between worst-case scenario and average-case, what do you learn from this?

# %%
#################################################
# Insert your code here
#################################################
plt.legend(['Element is exist', 'Element is non-exist'])

# %% [markdown]
# ---

# %% [markdown]
# # Lab 3-3 Intersect(a, b, c)

# %% [markdown]
# ## 3.1 Write a function `isIntersect(a, b, c)` with 2 variations where a, b, c are list of length *n*
# * Return True if list a, b, and c has a single element that is identical
# * Return False otherwise
#
# ## Constraints
# - Use basic loops and if-else only
#
# ## Example Test Case
# * isIntersect([50, 20, 80], [40, 30, 20], [20, 70, 90])
#     * Return True because 20 exists on all 3 lists
# * isIntersect([40, 60, 80, 100], [10, 30, 50, 60], [10, 20, 30, 40])
#     * Return False because no any number that exist on all 3 lists

# %% [markdown]
# 1. This function has an O($n^3$)

# %%
def isIntersect_1(a, b, c):
    #######################
    # Insert your code here
    #######################
    pass

# %%
isIntersect_1([50, 20, 80], [40, 30, 20], [20, 70, 90])

# %%
isIntersect_1([40, 60, 80, 100], [10, 30, 50, 60], [10, 20, 30, 40])

# %% [markdown]
# 2. This function has an O($n^2$)

# %%
def isIntersect_2(a, b, c):
    #######################
    # Insert your code here
    #######################
    pass

# %%
isIntersect_2([50, 20, 80], [40, 30, 20], [20, 70, 90])

# %%
isIntersect_2([40, 60, 80, 100], [10, 30, 50, 60], [10, 20, 30, 40])

# %% [markdown]
# How to create a random list of random length within a length of `n` (i.e. between 1 and `n`)
#
# For example,
# * In a list, each number is randomly chosen between 1 and 100
#     * Any number can appear in the list more than once
# * Each list has a random length between 1 and 20.

# %%
a = [random.randint(1,100) for _ in range(random.randint(1,20))]
b = [random.randint(1,100) for _ in range(random.randint(1,20))]
c = [random.randint(1,100) for _ in range(random.randint(1,20))]

print(a)
print(b)
print(c)

# %% [markdown]
# ## 3.2 Compare running time between isIntersect with O($n^3$) and O($n^2$) on a single plot
# * Setup the experiment by creating a, b, and c as a list of random length between 1 and `n` where each element is randomly chosen between 1 and 100.
# * Your plot should include x and y label, a legend, and a title
# * Each test should execute `100` rounds

# %%
ns5 = np.linspace(10, 1000, 100, dtype=int)
ts5 = []
ts6 = []

for i, s in enumerate(ns5):
    a = ## Add your code here
    b = ## Add your code here
    c = ## Add your code here
    s5 = timeit.timeit(
        ############################
        ## Add your code here
        ############################
    )
    ts5.append(s5)
    
    s6 = timeit.timeit(
        ############################
        ## Add your code here
        ############################
    )
    ts6.append(s6)

# %% [markdown]
# Add important information to your plot

# %%
plt.plot(ns5, ts5, 'or');
plt.plot(ns5, ts6, 'ob');
# Insert your code here

# %% [markdown]
# What does this plot tells you?

# %% [markdown]
# ---
